# %%
import pandas as pd
df= pd.read_csv("cleaned_data.csv")
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   18       Yes      Travel_Rarely        230  Research & Development
# 1   18        No      Travel_Rarely        812                   Sales
# 2   18       Yes  Travel_Frequently       1306                   Sales
# 3   18        No         Non-Travel        287  Research & Development
# 4   18       Yes         Non-Travel        247  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 3          3  Life Sciences             405
# 1                10          3        Medical             411
# 2                 5          3      Marketing             614
# 3                 5          2  Life Sciences            1012
# 4                 8          1        Medical            1156
#
#    EnvironmentSatisfaction  ... MonthlyRate  OverTime  PercentSalaryHike  \
# 0                        3  ...       25233        No                 13
# ...

# %%
df.shape
# Out:
# (1470, 27)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MonthlyIncome',
#        'MonthlyRate', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeNumber            1470 non-null   int64
#  9   EnvironmentSatisfaction   1470 non-null   int64
#  10  Gender                    1470 non-null   object
#  11  HourlyRate                1470 non-null   int64
#  12  JobInvolvement            1470 non-null   int64
#  13  JobLevel                  1470 non-null   int64
# ...

# %%
df.isnull()
# Out:
#         Age  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False      False           False      False       False
# 1     False      False           False      False       False
# 2     False      False           False      False       False
# 3     False      False           False      False       False
# 4     False      False           False      False       False
# ...     ...        ...             ...        ...         ...
# 1465  False      False           False      False       False
# 1466  False      False           False      False       False
# 1467  False      False           False      False       False
# 1468  False      False           False      False       False
# 1469  False      False           False      False       False
#
#       DistanceFromHome  Education  EducationField  EmployeeNumber  \
# 0                False      False           False           False
# 1                False      False           False           False
# ...

# %%
df.head(5)
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   18       Yes      Travel_Rarely        230  Research & Development
# 1   18        No      Travel_Rarely        812                   Sales
# 2   18       Yes  Travel_Frequently       1306                   Sales
# 3   18        No         Non-Travel        287  Research & Development
# 4   18       Yes         Non-Travel        247  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 3          3  Life Sciences             405
# 1                10          3        Medical             411
# 2                 5          3      Marketing             614
# 3                 5          2  Life Sciences            1012
# 4                 8          1        Medical            1156
#
#    EnvironmentSatisfaction  ... MonthlyRate  OverTime  PercentSalaryHike  \
# 0                        3  ...       25233        No                 13
# ...

# %%
import matplotlib.pyplot as plt
sizes = df['Attrition'].value_counts()
categories = sizes.index

custom_colors = ['lightcoral', 'lightskyblue']
slice_explode = (0.1, 0)

plt.pie(
    sizes,
    explode=slice_explode,
    labels=categories,
    colors=custom_colors,
    autopct='%1.1f%%',
    shadow=True,
    startangle=140
)


plt.title("Attrition Distribution")
plt.axis('equal')
# Out:
# (np.float64(-1.0641964133990227),
#  np.float64(1.135803447991428),
#  np.float64(-1.1980392677615292),
#  np.float64(1.1046674518305273))

# %%
import matplotlib.pyplot as plt

categories = df['Department'].value_counts()
bar=plt.bar(categories.index, categories.values, color=['lightskyblue', 'lightcoral', 'lightgreen'], edgecolor='black', width=0.6)
plt.bar_label(bar, padding=1, fontsize=11)

plt.title('Workforce Size by Department',fontweight='bold',fontsize=12)
plt.xlabel('Department',fontsize=12)
plt.ylabel('Number of Employees',fontsize=12)
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df['MonthlyIncome'], bins=20, edgecolor='black', color='skyblue')
plt.title('Monthly Income Distribution')
plt.xlabel('Monthly Income')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

attrition_overtime_counts = df.groupby(['OverTime', 'Attrition']).size().unstack(fill_value=0)
ax = attrition_overtime_counts.plot(kind='bar', stacked=True, figsize=(6,5), color={'Yes': 'lightcoral', 'No': 'lightskyblue'})

plt.title('Attrition vs. OverTime (Stacked Bar Chart)', fontsize=14, fontweight='bold')
plt.xlabel('OverTime', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)
plt.xticks(rotation=0)
plt.legend(title='Attrition')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,5))
sns.histplot(df['Age'], bins=20, color='skyblue', edgecolor='black', stat='density', alpha=0.7)
sns.kdeplot(df['Age'], color='red', lw=1, label='KDE', alpha=0.9)

plt.title('Age Distribution with KDE Overlay')
plt.xlabel('Age')
plt.ylabel('Density')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

job_satisfaction_attrition = pd.crosstab(df['JobSatisfaction'], df['Attrition'])

plt.figure(figsize=(6,5))
sns.heatmap(job_satisfaction_attrition, annot=True, fmt='d', cmap='YlGnBu', linewidths=.5)

plt.title('Job Satisfaction vs. Attrition Heatmap', fontsize=14, fontweight='bold')
plt.xlabel('Attrition', fontsize=12)
plt.ylabel('Job Satisfaction', fontsize=12)
plt.show()

# %% [markdown]
# ### Experience vs. Salary Scatter Plot
#
# This scatter plot visualizes the relationship between an employee's total working years (experience) and their monthly income.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5,6))
sns.scatterplot(x='TotalWorkingYears', y='MonthlyIncome', data=df, hue='Attrition', palette='magma', alpha=0.7)

plt.title('Experience (Total Working Years) vs. Monthly Income', fontsize=14, fontweight='bold')
plt.xlabel('Total Working Years', fontsize=12)
plt.ylabel('Monthly Income', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(title='Attrition')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### WorkLifeBalance vs. Attrition Box Plot
#
# This box plot visualizes the distribution of 'WorkLifeBalance' for employees who stayed and those who left, providing insights into how work-life balance might influence attrition.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,5))
sns.boxplot(x='Attrition', y='WorkLifeBalance', data=df, hue='Attrition', palette='viridis', legend=False)

plt.title('WorkLifeBalance vs. Attrition', fontsize=14, fontweight='bold')
plt.xlabel('Attrition', fontsize=12)
plt.ylabel('WorkLifeBalance', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import plotly.express as px

# Prepare data for the donut chart
donut_data = df.groupby(['Department', 'Attrition']).size().reset_index(name='Count')

fig = px.sunburst(donut_data,
                  path=['Department', 'Attrition'],
                  values='Count',
                  color='Attrition',
                  color_discrete_map={'Yes': 'red', 'No': 'green'},
                  title='Employee Attrition Distribution by Department')

fig.update_layout(uniformtext=dict(minsize=10, mode='hide'),width=600,height=500)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Employee Attrition Prediction Model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
ml_df = df.copy()

# %%
ml_df['Attrition'] = ml_df['Attrition'].map({
    'Yes':1,
    'No':0
})

# %%
features = [
    'Age',
    'MonthlyIncome',
    'JobSatisfaction',
    'WorkLifeBalance',
    'TotalWorkingYears',
    'YearsAtCompany'
]

# %%
ml_df["OverTime"]=ml_df["OverTime"].map({
    "Yes":1,
    "No":0
})

# %%
features.append("OverTime")

# %%
X=ml_df[features]
Y=ml_df["Attrition"]

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.2,
    random_state=42
)

# %%
model=LogisticRegression(max_iter=1000, class_weight="balanced")
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000)

# %%
Y_pred=model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, Y_pred)

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7380952380952381

# %%
print(confusion_matrix(Y_test, Y_pred))
# Out:
# [[179  62]
#  [ 15  38]]

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.74      0.82       241
#            1       0.38      0.72      0.50        53
#
#     accuracy                           0.74       294
#    macro avg       0.65      0.73      0.66       294
# weighted avg       0.82      0.74      0.76       294

# %%
importance = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_[0]
})

importance.sort_values(
    by='Coefficient',
    ascending=False
)
# Out:
#              Feature  Coefficient
# 6           OverTime     1.316385
# 5     YearsAtCompany     0.001331
# 1      MonthlyIncome    -0.000075
# 4  TotalWorkingYears    -0.020989
# 0                Age    -0.021017
# 2    JobSatisfaction    -0.308939
# 3    WorkLifeBalance    -0.310860

# %%
risk_scores = model.predict_proba(X_test)

# %%
risk_scores[:5]
# Out:
# array([[0.6259548 , 0.3740452 ],
#        [0.51032757, 0.48967243],
#        [0.69119609, 0.30880391],
#        [0.27917536, 0.72082464],
#        [0.46368121, 0.53631879]])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6, 5))

# Plot the distribution of the leaving probabilities (column index 1)
sns.histplot(risk_scores[:, 1], bins=20, kde=True, color='crimson', edgecolor='black')

plt.title('Overall Workforce Risk Distribution', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Risk Score (0.0 = Safe, 1.0 = High Risk of Leaving)', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %%
risk_df = X_test.copy()

risk_df['RiskScore'] = risk_scores[:,1]

# %%
risk_df.head()
# Out:
#       Age  MonthlyIncome  JobSatisfaction  WorkLifeBalance  TotalWorkingYears  \
# 1041   41           4393                2                3                 14
# 184    27          12808                4                3                  9
# 1222   46           5562                2                3                 19
# 67     23           2275                4                3                  3
# 220    28           4558                1                3                 10
#
#       YearsAtCompany  OverTime  RiskScore
# 1041               5         0   0.374045
# 184                9         1   0.489672
# 1222              10         0   0.308804
# 67                 3         1   0.720825
# 220               10         0   0.536319

# %%
def recommendation(score):

    if score >= 0.80:
        return "Immediate HR Intervention"

    elif score >= 0.50:
        return "Manager Discussion"

    else:
        return "Regular Monitoring"

# %%
risk_df['Recommendation'] = risk_df['RiskScore'].apply(recommendation)

# %%
risk_df[['RiskScore','Recommendation']].head(20)
# Out:
#       RiskScore      Recommendation
# 1041   0.374045  Regular Monitoring
# 184    0.489672  Regular Monitoring
# 1222   0.308804  Regular Monitoring
# 67     0.720825  Manager Discussion
# 220    0.536319  Manager Discussion
# 494    0.358765  Regular Monitoring
# 430    0.471584  Regular Monitoring
# 240    0.280720  Regular Monitoring
# 218    0.735637  Manager Discussion
# 49     0.516392  Manager Discussion
# 665    0.363544  Regular Monitoring
# 926    0.510138  Manager Discussion
# 617    0.336431  Regular Monitoring
# 361    0.774884  Manager Discussion
# 1423   0.137877  Regular Monitoring
# 1244   0.673807  Manager Discussion
# 1250   0.346179  Regular Monitoring
# 752    0.363442  Regular Monitoring
# 271    0.344641  Regular Monitoring
# 1055   0.508715  Manager Discussion
